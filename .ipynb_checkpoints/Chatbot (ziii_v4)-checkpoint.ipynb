# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /Users/mcabook/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/mcabook/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 321 documents
# 101 classes ['goodbye', 'greeting', 'negative', 'positive', 'problem:3M Maintenance', 'problem:4 axis clamp', 'problem:6M Maintenance', 'problem:ATC LS error', 'problem:BUE', 'problem:Burr formation', 'problem:Chipping', 'problem:Chipping1', 'problem:Chipping2', 'problem:Crater wear', 'problem:Door not close', 'problem:EDM', 'problem:Every week Maintenance', 'problem:Everyday Maintenance', 'problem:Flank wear 1', 'problem:Flank wear 2', 'problem:Flank wear 3', 'problem:Flank wear1', 'problem:Flank wear2', 'problem:Flank wear3', 'problem:Machine power', "problem:Machine's electric function", 'problem:PLC alarm', 'problem:Plastic deformation1', 'problem:Rotation direction', 'problem:T CODE = SP', 'problem:VMC1060', 'problem:VMC1270', 'problem:VMC1370', 'problem:VMC1580', 'problem:VMC1690', 'problem:VMC1890', 'problem:VMC540', 'problem:VMC650', 'problem:VMC850', 'problem:VMC960', 'problem:Vibration', 'problem:Vibration1', 'problem:Vibration2', 'problem:Vibration3', 'problem:Vibration4', 'problem:Vibration5', 'problem:Vibration6', 'problem:Vibration7', 'problem:Vibration8', 'problem:abnormal flank wear', 'problem:annual maintenance', 'problem:arm 270 error', 'problem:arm 90 error', 'problem:arm home pos error', 'problem:arm jog mode', 'problem:arm tool', 'problem:axis trouble', 'problem:broken cutter', 'problem:built-up edge 2', 'problem:built-up edge1', 'problem:chip jamming', 'problem:conical threads', 'problem:coolant pump', 'problem:crater wear', 'problem:every year Maintenance', 'problem:everyday maintenance', 'problem:flank wear', 'problem:heavy', 'problem:insert breakage', 'problem:lubrication pump', 'problem:machine inefficiency', 'problem:no coolant', 'problem:not flat', 'problem:not smooth', 'problem:notch wear', 'problem:plastic deformation', 'problem:plastic deformation2', 'problem:quarterly maintenance', 'problem:rapid flank water', 'problem:re-cutting of chips', 'problem:recutting of chips', 'problem:semiannual maintenance', 'problem:shakes', 'problem:spindle brake', 'problem:spindle rotation', 'problem:spindle trouble', 'problem:thermal cracks', 'problem:tight', 'problem:tool no. not found', 'problem:tool not clamp', 'problem:tool not in position', 'problem:tool not unclamp', 'problem:tool pot not down', 'problem:tool pot not up', 'problem:umbrella tool', 'problem:unsatisfactory surface finish', 'problem:unsatisfactory surface finish1', 'problem:unsatisfactory surface finish2', 'problem:unsatisfactory surface finish3', 'problem:unsatisfactory surface finish4', 'problem:vibration9']
# 429 unique lemmatized words ["'s", '(', ')', ',', '-', '.', '1000', '10000kg', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '100a', '1010', '1011', '1012', '1013', '1016', '1017', '1018', '1019', '1060', '10kva', '10mm2', '12000kg', '1270', '1370', '15000kg', '1580', '15kva', '1690', '16mm2', '18000kg', '1890', '20kva', '25mm2', '270', '3', '3500kg', '35kva', '4000kg', '40a', '4500kg', '4th', '5300kg', '540', '6', '60a', '650', '8000kg', '850', '90', '960', ':', '=', 'a', 'abnormal', 'above', 'abrasive', 'against', 'agree', 'air', 'alarm', 'aluminium', 'amount', 'and', 'angle', 'annual', 'annually', 'anti', 'anyone', 'are', 'arm', 'atc', 'away', 'awesome', 'axially', 'axis', 'back', 'back-cutting', 'bad', 'battery', 'be', 'big', 'brake', 'breakage', 'breaker', 'breakthrough', 'brittle', 'broken', 'bue', 'built-up', 'burr', 'by', 'bye', 'ca', 'can', 'carbon', 'cause', 'causing', 'centre', 'change', 'changing', 'chaos', 'check', 'chip', 'chipping', 'choose', 'chose', 'circuit', 'clamp', 'clamped', 'clamping', 'close', 'code', 'collant', 'collect', 'collet', 'component', 'conical', 'control', 'conveyor', 'coolant', 'cooler', 'corner', 'could', 'crack', 'crater', 'cut', 'cutter/', 'cutting', 'daily', 'damage', 'damaged', 'data', 'day', 'deflected', 'deformation', 'degree', 'deposit', 'depression', 'depth', 'diameter', 'diffusion', 'direction', 'discharge', 'discharging', 'do', 'doe', 'door', 'down', 'drain', 'drawing', 'dro', 'due', 'easy', 'edge', 'electric', 'emergency', 'emg', 'error', 'evacuation', 'every', 'everyday', 'excessive', 'execessive', 'f2', 'face', 'feed', 'feeling', 'find', 'finish', 'finsih', 'fire', 'fixture', 'fixturing', 'flank', 'flat', 'fluid', 'for', 'force', 'formation', 'found', 'fracture', 'frittering', 'from', 'fuild', 'function', 'fz', 'gear', 'generation', 'geometry', 'get', 'go', 'good', 'goodbye', 'grade', 'hammering', 'handle', 'happened', 'hardening', 'harmful', 'heat', 'heavy', 'height', 'hello', 'hi', 'high', 'high/low', 'highly', 'home', 'how', 'hrsa/stainless', 'hunting', 'hydraulic', 'impression', 'in', 'inadequate', 'inclination', 'incorrect', 'incorrectly', 'inefficiency', 'infeed', 'input', 'insert', 'instability', 'insufficient', 'intermittent', 'irregular', 'is', 'jamming', 'jog', 'keep', 'later', 'lead', 'leading', 'level', 'life', 'limit', 'limited', 'line', 'liquid', 'load', 'loaded', 'long', 'low', 'low-carbon', 'lube', 'lubrication', 'machince', 'machine', 'machining', 'mag', 'magazine', 'main', 'maintenance', 'material', 'mc', 'mechanism', 'method', 'middel', 'milled', 'milling', 'mode', 'model', 'month', 'motor', "n't", 'negative', 'net', 'nice', 'no', 'noise', 'nope', 'normally', 'nose', 'not', 'notch', 'nothing', 'number', 'occurs', 'of', 'often', 'oil', 'ol', 'on', 'or', 'orientation', 'origin', 'ot', 'out', 'over', 'overactive', 'overhang', 'overloaded', 'part', 'per', 'perfect', 'perform', 'perpendicular', 'plastic', 'point', 'poisiton', 'poor', 'position', 'positioned', 'power', 'pressure', 'prior', 'processing', 'pump', 'quarter', 'quarterly', 'radial', 'rake', 'rapid', 're-cutting', 'reach', 'resistance', 'resulting', 'revolution', 'ripped', 'rotate', 'rotation', 'rpm', 'run-out', 'scale', 'security', 'see', 'semiannual', 'sensor', 'series', 'set-up', 'shake', 'shallow', 'short', 'shoulder', 'side', 'signal', 'six', 'skin', 'sleeve', 'small', 'smooth', 'sp', 'specific', 'speed', 'spindle', 'square', 'stability', 'stainless', 'start', 'steel', 'sticky', 'stop', 'such', 'supply', 'support', 'surface', 't', 'table', 'tcode', 'temperature', 'texture', 'thanks', 'that', 'the', 'then', 'there', 'thermal', 'thread', 'threading', 'three', 'tight', 'to', 'together', 'tolerance', 'too', 'tool', 'toolmagazine', 'top', 'torn', 'tough', 'trailing', 'tre', 'trouble', 'turned', 'umbrella', 'unclamp', 'uneven', 'unsatisfactory', 'unstable', 'unsuitable', 'upward', 'variation', 'varying', 'vc', 'very', 'vibration', 'vmc', 'water', 'weak', 'weakend', 'weakened', 'w ...

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
#
200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0830 - accuracy: 0.6355
# Epoch 112/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9578 - accuracy: 0.6667
# Epoch 113/200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.9620 - accuracy: 0.6636: 0s - loss: 0.9862 - accuracy: 0.
# Epoch 114/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0599 - accuracy: 0.6355
# Epoch 115/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0013 - accuracy: 0.6417
# Epoch 116/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0419 - accuracy: 0.6449
# Epoch 117/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9683 - accuracy: 0.6511
# Epoch 118/200
# 65/65 [==============================] - 0s 3ms/step - loss: 1.1297 - accuracy: 0.6324
# Epoch 119/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0387 - accuracy: 0.6791
# Epoch 120/200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.8958 - accuracy: 0.6947
# Epoch 121/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0672 - accuracy: 0.6480
# Epoch 122/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9301 - accuracy: 0.6791
# Epoch 123/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9688 - accuracy: 0.6480
# Epoch 124/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0354 - accuracy: 0.6168
# Epoch 125/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9713 - accuracy: 0.6480
# Epoch 126/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0096 - accuracy: 0.6417
# Epoch 127/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9070 - accuracy: 0.6885
# Epoch 128/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9684 - accuracy: 0.6698
# Epoch 129/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9818 - accuracy: 0.6480
# Epoch 130/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8586 - accuracy: 0.6947
# Epoch 131/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8885 - accuracy: 0.6822
# Epoch 132/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0565 - accuracy: 0.6262
# Epoch 133/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8772 - accuracy: 0.6978
# Epoch 134/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0515 - accuracy: 0.6199
# Epoch 135/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9451 - accuracy: 0.6729
# Epoch 136/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9681 - accuracy: 0.6355
# Epoch 137/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9509 - accuracy: 0.6667
# Epoch 138/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9228 - accuracy: 0.6760
# Epoch 139/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9889 - accuracy: 0.6542
# Epoch 140/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9187 - accuracy: 0.6573
# Epoch 141/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9950 - accuracy: 0.6667
# Epoch 142/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8843 - accuracy: 0.6667
# Epoch 143/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0400 - accuracy: 0.6355
# Epoch 144/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9036 - accuracy: 0.6636
# Epoch 145/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9326 - accuracy: 0.6729
# Epoch 146/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9462 - accuracy: 0.6791
# Epoch 147/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8797 - accuracy: 0.6978
# Epoch 148/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0250 - accuracy: 0.6386
# Epoch 149/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9782 - accuracy: 0.6480
# Epoch 150/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0338 - accuracy: 0.6667
# Epoch 151/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0120 - accuracy: 0.6573
# Epoch 152/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9155 - accuracy: 0.6636
# Epoch 153/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8759 - accuracy: 0.6885
# Epoch 154/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9075 - accuracy: 0.6791
# Epoch 155/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9413 - accuracy: 0.6417
# Epoch 156/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8596 - accuracy: 0.6885
# Epoch 157/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8744 - accuracy: 0.6978
# Epoch 158/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8945 - accuracy: 0.7009
# Epoch 159/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7989 - accuracy: 0.7072
# Epoch 160/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9628 - accuracy: 0.6760
# Epoch 161/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8567 - accuracy: 0.6885
# Epoch 162/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0052 - accuracy: 0.6729
# Epoch 163/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7466 - accuracy: 0.7040
# Epoch 164/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9016 - accuracy: 0.6511
# Epoch 165/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7909 - accuracy: 0.6978
# Epoch 166/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0055 - accuracy: 0.6511
# Epoch 167/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8439 - accuracy: 0.7040
# Epoch 168/200
# 65/65 [==============================] - 0s 3ms/step - loss: 0.9184 - accuracy: 0.6667
# Epoch 169/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8443 - accuracy: 0.7072
# Epoch 170/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8401 - accuracy: 0.6854
# Epoch 171/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8666 - accuracy: 0.6791
# Epoch 172/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7482 - accuracy: 0.7259
# Epoch 173/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9107 - accuracy: 0.6822
# Epoch 174/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8893 - accuracy: 0.6916
# Epoch 175/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8987 - accuracy: 0.6791
# Epoch 176/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8892 - accuracy: 0.6885
# Epoch 177/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8971 - accuracy: 0.6791
# Epoch 178/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8678 - accuracy: 0.6542
# Epoch 179/200
# 65/65 [==============================] - 0s 1ms/step - loss: 1.0385 - accuracy: 0.6417
# Epoch 180/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8961 - accuracy: 0.7009
# Epoch 181/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8459 - accuracy: 0.7134
# Epoch 182/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0255 - accuracy: 0.6542
# Epoch 183/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8270 - accuracy: 0.6822
# Epoch 184/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8820 - accuracy: 0.6760
# Epoch 185/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8370 - accuracy: 0.6760
# Epoch 186/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8434 - accuracy: 0.6822
# Epoch 187/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.7856 - accuracy: 0.6978
# Epoch 188/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8386 - accuracy: 0.6978
# Epoch 189/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8646 - accuracy: 0.6698
# Epoch 190/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.9082 - accuracy: 0.6760
# Epoch 191/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.9825 - accuracy: 0.6667
# Epoch 192/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.7597 - accuracy: 0.7383
# Epoch 193/200
# 65/65 [==============================] - 0s 2ms/step - loss: 1.0379 - accuracy: 0.6511
# Epoch 194/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8973 - accuracy: 0.6791
# Epoch 195/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8986 - accuracy: 0.7072
# Epoch 196/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8790 - accuracy: 0.6854
# Epoch 197/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8208 - accuracy: 0.7009
# Epoch 198/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8973 - accuracy: 0.6760
# Epoch 199/200
# 65/65 [==============================] - 0s 1ms/step - loss: 0.8136 - accuracy: 0.6760
# Epoch 200/200
# 65/65 [==============================] - 0s 2ms/step - loss: 0.8503 - accuracy: 0.7259
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.00001
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# If it's related to a particular issue, then it returns a response corresponding 
# to the most likely solution based on the 'confidence score'; if it's a general question
# then choose from the response list randomly.


def getResponse(ints, intents_json):
    if ints == []:
        return 'Sorry I dont quite get that'
    tag = ints[0]['intent']
    if tag.startswith('problem:'):
        result = sorted(prob_sol_dict[tag], key = prob_sol_dict[tag].get, reverse = True)[0]
        print(result)
        return result
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

#Matching the negative and positive feedback patterns and return "positive" or 'negative' as a string

def getFeedback(feedback, intents_json): # Returns Pos or Neg
    ints = predict_class(feedback, model)
    res = getResponse(ints, intents)
    print(ints,res)
    return res
        

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res,ints

# %%
#updates the priority of each possible solution by incrementing or substracting 1 from the total count

def updatePriority(solution,prob_tag, label):
    if prob_tag == '':
        return
    if label == 'positive':
        prob_sol_dict[prob_tag][solution] += 1
        print(prob_sol_dict[prob_tag])
    if label == 'negative':
        prob_sol_dict[prob_tag][solution] -= 1
        print(prob_sol_dict[prob_tag])

# %%
# A new data structure to store the multiple solutions with their frequency count(confidence score)
# {problem_tag1: {solution1: count1, solution2: count2,...},
#  problem _tag2: ...}

prob_sol_dict = {}

for item in intents['intents']:
    if item['tag'].startswith('problem:'):
        count_dict = {}
        for solution in item['responses']:
            count_dict[solution] = 1
        prob_sol_dict[item['tag']] = count_dict
prob_sol_dict[''] = 'puck'
print(prob_sol_dict)
# Out:
# {'problem:umbrella tool': {'Set Feed Rate knob as 0 under HANDWHEEL model, press RESET to get the tool magazine back.': 1}, 'problem:arm tool': {'Set Feed Rate knob as 0 under HANDWHEEL model, press RESET to get the tool magazine back': 1}, 'problem:axis trouble': {'Clean the axis cover': 1, 'Change the bearing': 1, 'If it is from Z axis, check it is loosen for the hammer and guide way is loosen or not. Check if the hammer chain and guide wheel is wearing or not.': 1}, 'problem:spindle trouble': {'Lubricate the spindle belt': 1, 'Adjust the belt tension': 1, 'Replace the spindle belt or spindle.': 1}, 'problem:coolant pump': {'Check if the coolant liquid is enough or not.': 1, 'Input water to exclude the air inside the coolan tank': 1, 'Check the power sequence.': 1, 'Check the thermal relay': 1, 'Replace the coolant': 1}, 'problem:lubrication pump': {'Check if the lubrication oil is enough or not.': 1, 'Check the oil filter': 1, 'Check if the oil is SHELL TONA68 or equal one': 1, 'Adjust or replace the valve.': 1, 'Replace the pump.': 1}, 'problem:PLC alarm': {"Z axis can't reach ATC - check if the 2nd home point of Z axis signal F96.2 is right or not": 1}, 'problem:tool not in position': {'1) Make the tool magazine forward/backward rotation by hand to see if the alarm can be eliminated, if 1027 alarm appears, operate the magnetic valve, by hand and rotate the tool magazine by hand too, then eliminate the alarm 2) Check if the sensor switch is broken or not': 1}, 'problem:tool pot not down': {'Check the circuit': 1}, 'problem:tool no. not found': {'Please re-tidy the tool number': 1}, 'problem:arm 90 error': {'Replace the sensor': 1}, 'problem:tool not unclamp': {'Check the limit switch of tool loosen': 1}, 'problem:arm 270 error': {'check the sensor switch': 1}, 'problem:tool pot not up': {'Check sensor switch and circuit': 1}, 'problem:arm jog mode': {'Restart the controller': 1}, 'problem:tool not clamp': {'Check the limit switch': 1}, 'problem:arm home pos error': {'check the sensor switch': 1}, 'problem:ATC LS error': {'Check the spindle tool loosen/clamp can test the signal at the same time, adjust the limit position': 1}, 'problem:T CODE = SP': {'Reset the tool magazine when Tcode is not equal to spindle tool': 1}, 'problem:Door not close': {'Shut the door': 1}, 'problem:4 axis clamp': {'Clmap the 4th well': 1}, 'problem:VMC540': {'Machine model: VMC 540, Net Weight: 3500KG, Main Power: 10KVA, Circuit breaker: 40A, Power line diameter: 10mm2': 1}, 'problem:VMC650': {'Machine model: VMC 650, Net Weight: 4500KG, Main Power: 15KVA, Circuit breaker: 40A, Power line diameter: 10mm2': 1}, 'problem:VMC850': {'Machine model: VMC 850, Net Weight: 5300KG, Main Power: 15KVA, Circuit breaker: 40A, Power line diameter: 10mm2': 1}, 'problem:VMC960': {'Machine model: VMC 960, Net Weight: 4000KG, Main Power: 15KVA, Circuit breaker: 40A, Power line diameter: 10mm2': 1}, 'problem:VMC1060': {'Machine model: VMC 1060, Net Weight: 8000KG, Main Power: 20KVA, Circuit breaker: 60A, Power line diameter: 16mm2': 1}, 'problem:VMC1270': {'Machine model: VMC 1270, Net Weight: 10000KG, Main Power: 20KVA, Circuit breaker: 60A, Power line diameter: 16mm2': 1}, 'problem:VMC1370': {'Machine model: VMC 1370, Net Weight: 12000KG, Main Power: 35KVA, Circuit breaker: 100A, Power line diameter: 25mm2': 1}, 'problem:VMC1580': {'Machine model: VMC 1580, Net Weight: 15000KG, Main Power: 35KVA, Circuit breaker: 100A, Power line diameter: 25mm2': 1}, 'problem:VMC1690': {'Machine model: VMC 1690, Net Weight: 18000KG, Main Power: 35KVA, Circuit breaker: 100A, Power line diameter: 25mm2': 1}, 'problem:VMC1890': {'Machine model: VMC 1890, Net Weight: 18000KG, Main Power: 35KVA, Circuit breaker: 100A, Power line diameter: 25mm2': 1}, "problem:Machine's electric function": {"1) Circuit Breakers are used as machine's overload and circuit short protect. 2) Soft limit and mechanic limit has been set on the machine.": 1}, 'problem:Everyday Maintenance': {'As we required i ...

# %%
#Creating GUI with tkinter

import smtplib
from smtplib import SMTPException
import tkinter
from tkinter import *
import tkinter.ttk as ttk
import webbrowser

current_solution = ''
current_prob_tag = ''
wrong_answer = 0
warranty_asked = False 

global user_email
global receiver_email
global subj
global password
global body

def send():
    global current_solution
    global current_prob_tag
    global wrong_answer
    global temp_sol_dict
    global warranty_asked
    
    end_of_problem = False
    passed = False   
        
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)


    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#ffffff", font=("Arial", 12 ))

        res, probs_dict = chatbot_response(msg)
        tag = probs_dict[0]['intent']
        
        
        if wrong_answer >0:
            
            if tag == 'positive':
                
                end_of_problem = True
                wrong_answer = 0
                
                if warranty_asked:
                    warranty_asked = False
                    ChatLog.insert(END, "Kwahz Bot: Please consult your warranty and send your machine back if necessary" '\n\n')
                    
                else:
                    print('---Feedback running---')
                    updatePriority(current_solution, current_prob_tag, tag)

            if tag == 'negative':
                
                if warranty_asked:
                    ChatLog.insert(END, "Kwahz Bot: Please give us a feedback via email" '\n\n')
                    end_of_problem = True
                    wrong_answer = 0
                    passed = True
                    warranty_asked = False
                else:    
                    print('---Feedback running---')
                    updatePriority(current_solution, current_prob_tag, tag)
                    wrong_answer += 1
                    temp_sol_dict.pop(current_solution)
                    passed = True
                    
                    if not temp_sol_dict:
                        ChatLog.insert(END, "Kwahz Bot: Do you have a warranty?" '\n\n')
                        warranty_asked = True
                    else:
                        current_solution = sorted(temp_sol_dict,key = temp_sol_dict.get, reverse = True)[0]
                        print(current_solution)
                        ChatLog.insert(END, "Bot: " + current_solution + '\n\n')
                

        #Identifies problems from a message
        elif tag.startswith('problem:'):
            print(tag)
            current_solution = res
            current_prob_tag = tag
            print(current_solution)

        # Identifies feedback from a message
        elif tag == 'positive':
            print('---Feedback running---')
            updatePriority(current_solution, current_prob_tag, tag)
            end_of_problem = True
            wrong_answer = 0

        elif tag == 'negative':
            if current_solution != '':
                
                print('---Feedback running---')
                updatePriority(current_solution, current_prob_tag, tag)
                wrong_answer += 1

                # Now assign the alternative solution
                temp_sol_dict = prob_sol_dict[current_prob_tag].copy()
                temp_sol_dict.pop(current_solution)

                #Checking empty dictionary
                if not temp_sol_dict:
                    ChatLog.insert(END, "Kwahz Bot: Do you have a warranty?" '\n\n')
                    warranty_asked = True
                    passed = True
                else:
                    current_solution = sorted(temp_sol_dict,key = temp_sol_dict.get, reverse = True)[0]
                    print(current_solution)
                    ChatLog.insert(END, "Kwahz Bot: " + current_solution + '\n\n')
                    passed = True
                
        if not passed:
            ChatLog.insert(END, "Kwahz Bot: " + res + '\n\n')
        if end_of_problem:
            current_solution = ''
            current_prob_tag = ''
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
ttk.Style().theme_use('alt')
base.title("Chatbot")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

def gmail():   
    usermail = user_email.get()
    receivermail=receiver_email.get()           
    server=smtplib.SMTP('smtp.gmail.com:587')
    pass_word=password.get()
    subject=subj.get()
    #This allow you to include a subject by adding from, to and subject 
    line
    main_message=body.get('1.0', 'end-1c')
    Body="""From: Name here <usermail>
    To: <receivermail>
    Subject:%s 

    # %s
    """ %(subject,main_message )

    try:
            server=smtplib.SMTP('smtp.gmail.com:587')
            server.ehlo()
            server.starttls()
            server.login(usermail, pass_word  )
            server.sendmail(usermail,receivermail, Body )

            text.insert(1.0, 'message sent')
         #error handling
    except  (smtplib.SMTPException,ConnectionRefusedError,OSError):
            text.insert(1.0, 'message not sent')

            
def openNewWindow(): 
      
    # Toplevel object which will  
    # be treated as a new window 
       
    root= Tk(className=" Gmail app " )
    root.config(bg="#242424", )
     
    
    #user mail
    user_email = Label(root, font="Arial", text="Enter your Gmail address:  ")
    user_email.pack()
    user_email.config(bg="#242424", fg="white")
    user_email = Entry(root, bd =8)
    user_email.pack(fill=X)
    
    #receiver email
    receiver_email = Label(root, font = "Arial", text="Enter the recipient's email address:")
    receiver_email.pack()
    receiver_email.config(bg="#242424", fg="white")
    receiver_email = Entry(root, bd =8)
    receiver_email.pack(fill=X)
    
    #subject line
    subj= Label(root, font = "Arial", text="Enter your subject here: ")
    subj.pack()
    subj.config(bg="#242424", fg="white")
    
    subj = Entry(root, bd =8)
    subj.pack(fill=X)

    #Body of the message
    body = Text(root, font="Arial",  relief=FLAT , bd=8)
    body.config(bg="#ffffff", height=15)
    body.pack(fill=BOTH, expand=True)
    
    #password widget
    password = Label(root, font="Arial", text="Enter your Gmail password:  ")
    password.pack()
    password.config(bg="#242424", fg="white")
    
    password= Entry(root, show='*', bd =8)
    password.pack(fill=X)

    #submit button
    submit_mail = Button(root, font=("Arial Narrow",12,'bold'), text="Send",  bd=8, bg="#000000", activebackground="#919191", fg='#ffffff',command=gmail)
    submit_mail.pack(fill=X)
    
def gmail():   
    usermail = user_email.get()
    receivermail=receiver_email.get()           
    server=smtplib.SMTP('smtp.gmail.com:587')
    pass_word=password.get()
    subject=subj.get()
    #This allow you to include a subject by adding from, to and subject 
    line
    main_message=body.get('1.0', 'end-1c')
    Body="""From: Name here <usermail>
    To: <receivermail>
    Subject:%s 

    # %s
    """ %(subject,main_message )

    try:
            server=smtplib.SMTP('smtp.gmail.com:587')
            server.ehlo()
            server.starttls()
            server.login(usermail, pass_word  )
            server.sendmail(usermail,receivermail, Body )

            text.insert(1.0, 'message sent')
         #error handling
    except  (smtplib.SMTPException,ConnectionRefusedError,OSError):
            text.insert(1.0, 'message not sent')
            
new = 1
url = "https://www.google.com"

def openweb():
    webbrowser.open(url,new=new)

#Create Chat window
ChatLog = Text(base, bd=0, bg="#242424", fg='#ffffff', height="8", width="50", font="Calibri")

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview)
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Arial Narrow",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#ffffff", activebackground="#919191",fg='#000000',
                    command= send)

EmailButton = Button(base, font=("Arial Narrow",12,'bold'), text="Email", width="12", height=5,
                    bd=0, bg="#ffffff", activebackground="#919191",fg='#000000',
                    command= openNewWindow)
WebsiteButton = Button(base, font=("Arial Narrow",12,'bold'), text="Visit our website", width="12", height=5,
                    bd=0, bg="#ffffff", activebackground="#919191",fg='#000000',
                    command=openweb)

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="#242424",fg='#ffffff',width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=36, height=356, width=370)
EntryBox.place(x=128, y=401, height=90, width=248)
SendButton.place(x=6, y=401, height=90)
EmailButton.place(x=320, y=10, height=20, width=50)
WebsiteButton.place(x=6, y=10, height=20, width=150)

base.mainloop()
